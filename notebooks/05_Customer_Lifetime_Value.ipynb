# %% [markdown]
# # Customer Lifetime Value (CLV) Analysis
#
# ## Customer Segmentation and Customer Lifetime Value (CLV) Analysis
#
# **Dataset:** Customer Segments
#
# ### Objectives
# - Load the customer segmentation dataset
# - Calculate Customer Lifetime Value (CLV)
# - Rank customers by CLV
# - Categorize customers into High, Medium, and Low Value
# - Save the CLV dataset

# %%
import sys
import os

# Add project root to Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

import pandas as pd
import numpy as np
